# %%
from neuropil_utils import load_zstack_tiff, load_images_from_directory
import numpy as np

# %%
dendrite_dir = "/Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/dendrite"
axon_dir = "/Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon"
others_dir = "/Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others"

# %%
dendrite = load_images_from_directory(dendrite_dir)
axon = load_images_from_directory(axon_dir)
others = load_images_from_directory(others_dir)

dendrite_images = np.array(dendrite[0])
axon_images = np.array(axon[0])
others_images = np.array(others[0])
# Out:
# Loaded: 0000.png
# Loaded: 0001.png
# Loaded: 0002.png
# Loaded: 0003.png
# Loaded: 0004.png
# Loaded: 0005.png
# Loaded: 0006.png
# Loaded: 0007.png
# Loaded: 0008.png
# Loaded: 0009.png
# Loaded: 0010.png
# Loaded: 0011.png
# Loaded: 0012.png
# Loaded: 0013.png
# Loaded: 0014.png
# Loaded: 0015.png
# Loaded: 0016.png
# Loaded: 0017.png
# Loaded: 0018.png
# Loaded: 0019.png
# Loaded: 0020.png
# Loaded: 0021.png
# Loaded: 0022.png
# Loaded: 0023.png
# Loaded: 0024.png
# Loaded: 0025.png
# Loaded: 0026.png
# Loaded: 0027.png
# Loaded: 0028.png
# Loaded: 0029.png
# Loaded: 0030.png
# Loaded: 0031.png
# Loaded: 0032.png
# Loaded: 0033.png
# Loaded: 0034.png
# Loaded: 0035.png
# Loaded: 0036.png
# Loaded: 0037.png
# Loaded: 0038.png
# Loaded: 0039.png
# Loaded: 0040.png
# Loaded: 0041.png
# Loaded: 0042.png
# Loaded: 0043.png
# Loaded: 0044.png
# Loaded: 0045.png
# Loaded: 0046.png
# Loaded: 0047.png
# Loaded: 0048.png
# Loaded: 0049.png
# Loaded: 0050.png
# Loaded: 0051.png
# Loaded: 0052.png
# Loaded: 0053.png
# Loaded: 0054.png
# Loaded: 0055.png
# Loaded: 0056.png
# Loaded: 0057.png
# Loaded: 0058.png
# Loaded: 0059.png
# Loaded: 0060.png
# Loaded: 0061.png
# Loaded: 0062.png
# Loaded: 0063.png
# Loaded: 0064.png
# Loaded: 0065.png
# Loaded: 0066.png
# Loaded: 0067.png
# Loaded: 0068.png
# Loaded: 0069.png
# Loaded: 0070.png
# Loaded: 0071.png
# Loaded: 0072.png
# Loaded: 0073.png
# Loaded: 0074.png
# Loaded: 0075.png
# Loaded: 0076.png
# Loaded: 0077.png
# Loaded: 0078.png
# Loaded: 0079.png
# Loaded: 0080.png
# Loaded: 0081.png
# Loaded: 0082.png
# Loaded: 0083.png
# Loaded: 0084.png
# Loaded: 0085.png
# Loaded: 0086.png
# Loaded: 0087.png
# Loaded: 0088.png
# Loaded: 0089.png
# Loaded: 0090.png
# Loaded: 0091.png
# Loaded: 0092.png
# Loaded: 0093.png
# Loaded: 0094.png
# Loaded: 0095.png
# Loaded: 0096.png
# Loaded: 0097.png
# Loaded: 0098.png
# Loaded: 0099.png
# Loaded: 0100.png
# Loaded: 0101.png
# Loaded: 0102.png
# Loaded: 0103.png
# Loaded: 0104.png
# Loaded: 0105.png
# Loaded: 0106.png
# Loaded: 0152.png
# Loaded: 0153.png
# Loaded: 0154.png
# Loaded: 0155.png
# Loaded: 0156.png
# Loaded: 0157.png
# Loaded: 0158.png
# Loaded: 0159.png
# Loaded: 0160.png
# Loaded: 0161.png
# Loaded: 0162.png
# Loaded: 0163.png
# Loaded: 0164.png
# Loaded: 0165.png
# Loaded: 0166.png
# Loaded: 0167.png
# Loaded: 0168.png
# Loaded: 0169.png
# Loaded: 0170.png
# Loaded: 0171.png
# Loaded: 0172.png
# Loaded: 0173.png
# Loaded: 0174.png
# Loaded: 0175.png
# Loaded: 0176.png
# Loaded: 0177.png
# Loaded: 0178.png
# Loaded: 0179.png
# Loaded: 0180.png
# Loaded: 0181.png
# Loaded: 0182.png
# Loaded: 0183.png
# Loaded: 0184.png
# Loaded: 0185.png
# Loaded: 0186.png
# Loaded: 0187.png
# Loaded: 0188.png
# Loaded: 0189.png
# Loaded: 0190.png
# Loaded: 0191.png
# Loaded: 0192.png
# Loaded: 0193.png
# Loaded: 0194.png
# Loaded: 0195.png
# Loaded: 0196.png
# Loaded: 0197.png
# Loaded: 0198.png
# Loaded: 0199.png
# Loaded: 0200.png
# Loaded: 0201.png
# Loaded: 0202.png
# Loaded: 0203.png
# Loaded: 0204.png
# Loaded: 0205.png
# Loaded: 0206.png
# Loaded: 0207.png
# Loaded: 0208.png

# %%
dendrite_images.shape, axon_images.shape
# Out:
# ((209, 700, 1321), (209, 700, 1321))

# %%
from skimage import measure

# Get unique labels for dendrite (excluding 0)
dendrite_unique = np.unique(dendrite_images)
dendrite_unique = dendrite_unique[dendrite_unique > 0]  # Remove background (0)

# Create relabeling mapping for dendrite
dendrite_relabeled = np.zeros_like(dendrite_images)
for new_label, old_label in enumerate(dendrite_unique, start=1):
    dendrite_relabeled[dendrite_images == old_label] = new_label

# Get unique labels for axon (excluding 0)
axon_unique = np.unique(axon_images)
axon_unique = axon_unique[axon_unique > 0]  # Remove background (0)

# Create relabeling mapping for axon
axon_relabeled = np.zeros_like(axon_images)
for new_label, old_label in enumerate(axon_unique, start=1):
    axon_relabeled[axon_images == old_label] = new_label

print(f"Dendrite images re-labeled: {dendrite_relabeled.shape}")
print(f"Dendrite unique labels: {len(dendrite_unique)} (1 to {len(dendrite_unique)})")
print(f"Axon images re-labeled: {axon_relabeled.shape}")
print(f"Axon unique labels: {len(axon_unique)} (1 to {len(axon_unique)})")
# Out:
# Dendrite images re-labeled: (209, 700, 1321)
# Dendrite unique labels: 35 (1 to 35)
# Axon images re-labeled: (209, 700, 1321)
# Axon unique labels: 26 (1 to 26)

# %%
dendrite_relabeled.max(), dendrite_relabeled.min(), axon_relabeled.max(), axon_relabeled.min()
# Out:
# (np.uint16(35), np.uint16(0), np.uint16(26), np.uint16(0))

# %%
import napari

# Create a napari viewer
viewer = napari.Viewer()

# Add dendrite relabeled as labels
viewer.add_labels(dendrite_relabeled, name='Dendrite Labels')

# Add axon relabeled as labels
viewer.add_labels(axon_relabeled, name='Axon Labels')

# Show the viewer
napari.run()
