# %%
import napari
import numpy as np
from pathlib import Path
from skimage import io
import os
from qtpy.QtWidgets import QWidget, QVBoxLayout, QHBoxLayout, QComboBox, QPushButton, QLabel
from qtpy.QtCore import Qt
from scipy import ndimage
from qtpy.QtWidgets import QFileDialog

# 画像が含まれたディレクトリのパスを指定
image_dir = "/Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/data/imagesTs-1.tif"
labels_dir = "/Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/"

dendrite_dir = "/Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/dendrite"
axon_dir = "/Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon"

# サポートされる画像形式
supported_formats = ('.png', '.jpg', '.jpeg', '.tiff', '.tif', '.bmp')

def load_zstack_tiff(file_path):
    """
    z-stackされたTIFF画像を読み込む関数
    """
    try:
        image = io.imread(file_path)
        print(f"Loaded z-stack TIFF: {Path(file_path).name}, shape: {image.shape}")
        return image
    except Exception as e:
        print(f"Error loading {file_path}: {e}")
        return None

def load_images_from_directory(directory_path, supported_formats):
    """
    指定されたディレクトリから画像を読み込む関数
    """
    directory = Path(directory_path)
    images = []
    names = []
    
    if directory.exists():
        for image_file in sorted(directory.iterdir()):
            if image_file.suffix.lower() in supported_formats:
                image = io.imread(image_file)
                images.append(image)
                names.append(image_file.stem)
                print(f"Loaded: {image_file.name}")
    else:
        print(f"Directory {directory_path} does not exist")

    return np.array(images), names

# 画像ファイルを読み込み
images = load_zstack_tiff(image_dir)
labels, _ = load_images_from_directory(labels_dir, supported_formats)
dendrite = load_images_from_directory(dendrite_dir, supported_formats)[0]
axon = load_images_from_directory(axon_dir, supported_formats)[0]

# z-stack画像として結合
images_z_stack = np.stack(images, axis=0)
labels_z_stack = np.stack(labels, axis=0)

dendrite_z_stack = np.stack(dendrite, axis=0)
axon_z_stack = np.stack(axon, axis=0)

# napariビューアーを作成
viewer = napari.Viewer()

# napariにz-stack画像として追加
viewer.add_image(images_z_stack, name="Images")
viewer.add_labels(labels_z_stack, name="Labels")
viewer.add_labels(dendrite_z_stack, name="Dendrite")
viewer.add_labels(axon_z_stack, name="Axon")

class LabelTransferWidget(QWidget):
    def __init__(self, viewer):
        super().__init__()
        self.viewer = viewer
        self.init_ui()
    
    def init_ui(self):
        layout = QVBoxLayout()
        layout.setSpacing(5)  # スペーシングを小さく
        
        # From layer selection
        from_layout = QHBoxLayout()
        from_layout.addWidget(QLabel("From:"))
        self.from_combo = QComboBox()
        self.from_combo.setMinimumWidth(100)  # 最小幅を設定
        from_layout.addWidget(self.from_combo)
        layout.addLayout(from_layout)
        
        # To layer selection
        to_layout = QHBoxLayout()
        to_layout.addWidget(QLabel("To:"))
        self.to_combo = QComboBox()
        self.to_combo.setMinimumWidth(100)
        to_layout.addWidget(self.to_combo)
        layout.addLayout(to_layout)
        
        # Point layer selection
        point_layout = QHBoxLayout()
        point_layout.addWidget(QLabel("Points:"))
        self.point_combo = QComboBox()
        self.point_combo.setMinimumWidth(100)
        point_layout.addWidget(self.point_combo)
        layout.addLayout(point_layout)
        
        # Buttons
        self.update_button = QPushButton("Update")
        self.update_button.clicked.connect(self.update_layer_lists)
        layout.addWidget(self.update_button)
        
        self.transfer_button = QPushButton("Cut & Paste")
        self.transfer_button.clicked.connect(self.transfer_labels)
        layout.addWidget(self.transfer_button)
        
        # ウィジェット全体のサイズを制限
        self.setMaximumWidth(200)
        layout.setContentsMargins(5, 5, 5, 5)
        
        self.setLayout(layout)
        self.update_layer_lists()
        
        # Connect to layer events
        self.viewer.layers.events.inserted.connect(self.update_layer_lists)
        self.viewer.layers.events.removed.connect(self.update_layer_lists)
    
    def update_layer_lists(self):
        self.from_combo.clear()
        self.to_combo.clear()
        self.point_combo.clear()
        
        for layer in self.viewer.layers:
            if hasattr(layer, 'data') and 'Labels' in str(type(layer)):
                self.from_combo.addItem(layer.name)
                self.to_combo.addItem(layer.name)
            elif hasattr(layer, 'data') and 'Points' in str(type(layer)):
                self.point_combo.addItem(layer.name)
    
    def transfer_labels(self):
        from_layer_name = self.from_combo.currentText()
        to_layer_name = self.to_combo.currentText()
        point_layer_name = self.point_combo.currentText()
        
        if not all([from_layer_name, to_layer_name, point_layer_name]):
            print("Please select all required layers")
            return
        
        from_layer = None
        to_layer = None
        point_layer = None
        
        for layer in self.viewer.layers:
            if layer.name == from_layer_name:
                from_layer = layer
            elif layer.name == to_layer_name:
                to_layer = layer
            elif layer.name == point_layer_name:
                point_layer = layer
        
        if not all([from_layer, to_layer, point_layer]):
            print("Could not find selected layers")
            return
        
        points = point_layer.data
        if len(points) == 0:
            print("No points found in point layer")
            return
        
        for point in points:
            point_indices = tuple(int(coord) for coord in point)
            
            if any(idx < 0 or idx >= dim for idx, dim in zip(point_indices, from_layer.data.shape)):
                continue
            
            label_value = from_layer.data[point_indices]
            
            if label_value == 0:
                continue
            
            label_mask = (from_layer.data == label_value)
            to_layer.data[label_mask] = label_value
            from_layer.data[label_mask] = 0
        
        point_layer.data = []
        from_layer.refresh()
        to_layer.refresh()
        point_layer.refresh()
        print(f"Labels transferred from '{from_layer_name}' to '{to_layer_name}' and points cleared")

class LabelSaveWidget(QWidget):
    def __init__(self, viewer):
        super().__init__()
        self.viewer = viewer
        self.save_directory = Path("saved_labels_png")
        self.init_ui()
    
    def init_ui(self):
        layout = QVBoxLayout()
        layout.setSpacing(5)
        
        # Layer selection
        layer_layout = QHBoxLayout()
        layer_layout.addWidget(QLabel("Layer:"))
        self.save_combo = QComboBox()
        self.save_combo.setMinimumWidth(100)
        layer_layout.addWidget(self.save_combo)
        layout.addLayout(layer_layout)
        
        # Directory selection - 短縮表示
        dir_layout = QVBoxLayout()
        dir_layout.addWidget(QLabel("Save Directory:"))
        self.dir_label = QLabel("saved_labels_png")
        self.dir_label.setStyleSheet("border: 1px solid gray; padding: 2px; font-size: 10px;")
        self.dir_label.setWordWrap(True)  # テキストの折り返しを有効に
        self.dir_label.setMaximumHeight(40)  # 高さを制限
        dir_layout.addWidget(self.dir_label)
        
        self.browse_button = QPushButton("Browse")
        self.browse_button.clicked.connect(self.browse_directory)
        dir_layout.addWidget(self.browse_button)
        layout.addLayout(dir_layout)
        
        # Buttons
        self.update_save_button = QPushButton("Update")
        self.update_save_button.clicked.connect(self.update_layer_list)
        layout.addWidget(self.update_save_button)
        
        self.save_button = QPushButton("Save PNG")
        self.save_button.clicked.connect(self.save_labels_as_png)
        layout.addWidget(self.save_button)
        
        # ウィジェット全体のサイズを制限
        self.setMaximumWidth(200)
        layout.setContentsMargins(5, 5, 5, 5)
        
        self.setLayout(layout)
        self.update_layer_list()
        
        self.viewer.layers.events.inserted.connect(self.update_layer_list)
        self.viewer.layers.events.removed.connect(self.update_layer_list)
    
    def browse_directory(self):
        directory = QFileDialog.getExistingDirectory(
            self, 
            "Select Directory to Save Labels",
            str(self.save_directory.parent)
        )
        if directory:
            self.save_directory = Path(directory)
            # パスを短縮して表示
            display_path = str(self.save_directory)
            if len(display_path) > 30:
                display_path = "..." + display_path[-27:]
            self.dir_label.setText(display_path)
    
    def update_layer_list(self):
        self.save_combo.clear()
        for layer in self.viewer.layers:
            if hasattr(layer, 'data') and 'Labels' in str(type(layer)):
                self.save_combo.addItem(layer.name)
    
    def save_labels_as_png(self):
        layer_name = self.save_combo.currentText()
        if not layer_name:
            print("Please select a layer to save")
            return
        
        selected_layer = None
        for layer in self.viewer.layers:
            if layer.name == layer_name:
                selected_layer = layer
                break
        
        if selected_layer is None:
            print("Could not find selected layer")
            return
        
        self.save_directory.mkdir(exist_ok=True)
        label_data = selected_layer.data
        
        for z_idx in range(label_data.shape[0]):
            slice_data = label_data[z_idx]
            slice_data = slice_data.astype(np.uint16)
            filename = self.save_directory / f"{z_idx:04d}.png"
            io.imsave(filename, slice_data)
        
        print(f"Saved {label_data.shape[0]} PNG files to {self.save_directory}")

# ウィジェットを作成して追加
transfer_widget = LabelTransferWidget(viewer)
viewer.window.add_dock_widget(transfer_widget, name="Transfer", area="left")

save_widget = LabelSaveWidget(viewer)
viewer.window.add_dock_widget(save_widget, name="Save", area="left")

napari.run()
# Out:
# Loaded z-stack TIFF: imagesTs-1.tif, shape: (209, 700, 1321)
# Loaded: 0000.png
# Loaded: 0001.png
# Loaded: 0002.png
# Loaded: 0003.png
# Loaded: 0004.png
# Loaded: 0005.png
# Loaded: 0006.png
# Loaded: 0007.png
# Loaded: 0008.png
# Loaded: 0009.png
# Loaded: 0010.png
# Loaded: 0011.png
# Loaded: 0012.png
# Loaded: 0013.png
# Loaded: 0014.png
# Loaded: 0015.png
# Loaded: 0016.png
# Loaded: 0017.png
# Loaded: 0018.png
# Loaded: 0019.png
# Loaded: 0020.png
# Loaded: 0021.png
# Loaded: 0022.png
# Loaded: 0023.png
# Loaded: 0024.png
# Loaded: 0025.png
# Loaded: 0026.png
# Loaded: 0027.png
# Loaded: 0028.png
# Loaded: 0029.png
# Loaded: 0030.png
# Loaded: 0031.png
# Loaded: 0032.png
# Loaded: 0033.png
# Loaded: 0034.png
# Loaded: 0035.png
# Loaded: 0036.png
# Loaded: 0037.png
# Loaded: 0038.png
# Loaded: 0039.png
# Loaded: 0040.png
# Loaded: 0041.png
# Loaded: 0042.png
# Loaded: 0043.png
# Loaded: 0044.png
# Loaded: 0045.png
# Loaded: 0046.png
# Loaded: 0047.png
# Loaded: 0048.png
# Loaded: 0049.png
# Loaded: 0050.png
# Loaded: 0051.png
# Loaded: 0052.png
# Loaded: 0053.png
# Loaded: 0054.png
# Loaded: 0055.png
# Loaded: 0056.png
# Loaded: 0057.png
# Loaded: 0058.png
# Loaded: 0059.png
# Loaded: 0060.png
# Loaded: 0061.png
# Loaded: 0062.png
# Loaded: 0063.png
# Loaded: 0064.png
# Loaded: 0065.png
# Loaded: 0066.png
# Loaded: 0067.png
# Loaded: 0068.png
# Loaded: 0069.png
# Loaded: 0192.png
# Loaded: 0193.png
# Loaded: 0194.png
# Loaded: 0195.png
# Loaded: 0196.png
# Loaded: 0197.png
# Loaded: 0198.png
# Loaded: 0199.png
# Loaded: 0200.png
# Loaded: 0201.png
# Loaded: 0202.png
# Loaded: 0203.png
# Loaded: 0204.png
# Loaded: 0205.png
# Loaded: 0206.png
# Loaded: 0207.png
# Loaded: 0208.png
# Labels transferred from 'Labels' to 'Axon' and points cleared
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0000.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0001.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0002.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0003.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0004.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0005.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0006.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0007.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0008.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0009.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0010.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0011.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0012.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0013.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0014.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0015.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0016.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0017.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0018.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0019.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0020.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0021.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0022.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0023.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0024.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0025.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0026.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0027.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0028.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0029.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0030.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0031.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0032.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0033.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0034.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0035.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0036.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0037.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0038.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0039.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0040.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0041.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0042.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0043.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0044.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0045.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0046.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0047.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0048.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0049.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0050.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0051.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0052.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0053.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0054.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0055.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0056.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0057.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0058.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0059.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0060.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0061.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0062.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0063.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0064.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0065.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0066.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0067.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0068.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0069.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0070.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0071.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0072.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0073.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0074.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0075.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0076.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0077.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0078.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0079.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0080.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0081.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0082.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0083.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0084.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0085.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0086.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0087.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0088.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0089.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0090.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0091.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0092.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0093.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0094.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0095.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0096.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0097.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0098.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0099.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0100.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0101.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0102.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0103.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0104.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0105.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0106.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0107.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0108.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0109.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0110.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0111.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0112.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0113.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0114.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0115.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0116.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0117.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0118.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0119.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0120.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0121.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0122.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0123.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0124.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0125.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0126.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0127.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0128.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0129.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0130.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0131.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0132.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0133.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0134.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0135.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0136.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0137.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0138.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0139.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0140.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0141.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0142.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0143.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0144.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/axon/0145.png is a low contrast image
#   io.imsave(filename, slice_data)
# ...
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0147.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0148.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0149.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0150.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0151.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0152.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0153.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0154.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0155.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0156.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0157.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0158.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0159.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0160.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0161.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0162.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0163.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0164.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0165.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0166.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0167.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0168.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0169.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0170.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0171.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0172.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0173.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0174.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0175.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0176.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0177.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0178.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0179.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0180.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0181.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0182.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0183.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0184.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0185.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0186.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0187.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0188.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0189.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0190.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0191.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0192.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0193.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0194.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0195.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0196.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0197.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0198.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0199.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0200.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0201.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0202.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0203.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0204.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0205.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0206.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0207.png is a low contrast image
#   io.imsave(filename, slice_data)
# /var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1501939698.py:287: UserWarning: /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others/0208.png is a low contrast image
#   io.imsave(filename, slice_data)
# Saved 209 PNG files to /Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/output/others

# %%
temp = viewer.layers['axon'].data
# Out:
# 2025-08-15 21:52:36.669 python[82554:20567070] error messaging the mach port for IMKCFRunLoopWakeUpReliable
# Traceback (most recent call last):
#   File "/var/folders/9g/_9g9gbr93_l2p9s0z7lzq7f00000gn/T/ipykernel_82554/1086947596.py", line 173, in transfer_labels
#     to_layer.data[label_mask] = label_value
#   File "/Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/scripts/.venv/lib/python3.9/site-packages/dask/array/core.py", line 1926, in __setitem__
#     dsk = setitem_array(out, self, key, value)
#   File "/Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/scripts/.venv/lib/python3.9/site-packages/dask/array/slicing.py", line 1646, in setitem_array
#     indices, implied_shape, reverse, implied_shape_positions = parse_assignment_indices(
#   File "/Users/sakanotakumi/Documents/000_Home/Work/Research/02_Experiments_data/E343/scripts/.venv/lib/python3.9/site-packages/dask/array/slicing.py", line 1335, in parse_assignment_indices
#     raise IndexError(
# IndexError: Incorrect shape ((209, 700, 1321)) of integer indices for dimension with size 209
